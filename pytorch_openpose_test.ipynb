# %% [markdown]
# <a href="https://colab.research.google.com/github/june1st/GoogleColab/blob/master/pytorch_openpose_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/Hzzone/pytorch-openpose

# %%
# !git clone https://github.com/Hzzone/pytorch-openpose
# Out:
# Cloning into 'pytorch-openpose'...
# remote: Enumerating objects: 93, done.
# remote: Total 93 (delta 0), reused 0 (delta 0), pack-reused 93
# Unpacking objects: 100% (93/93), done.

# %%
# %cd pytorch-openpose/
# Out:
# /content/pytorch-openpose

# %%
# !mkdir model
# %cd model
# !wget -O models.zip https://www.dropbox.com/sh/7xbup2qsn7vvjxo/AABWFksdlgOMXR_r5v3RwKRYa?dl=1
# !unzip -o models.zip
# %cd ..
# Out:
# /content/pytorch-openpose/model
# --2019-08-04 04:32:11--  https://www.dropbox.com/sh/7xbup2qsn7vvjxo/AABWFksdlgOMXR_r5v3RwKRYa?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/dl/7xbup2qsn7vvjxo/AABWFksdlgOMXR_r5v3RwKRYa [following]
# --2019-08-04 04:32:11--  https://www.dropbox.com/sh/dl/7xbup2qsn7vvjxo/AABWFksdlgOMXR_r5v3RwKRYa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7ad1f07f4f92178823a3ba26ae.dl.dropboxusercontent.com/zip_by_token_key?dl=1&key=Al_jctViyDUqPJowLg2KHcFswa7WOLnaPavvl6RnbPeM2quCLI0sBL6rIED0WlvAYQTbw9AtJPM_hkIsWurYeohk5gYvPxU7zZTAC1Reu61mm_331agmMUNAXIuSjX6SUOhT9UGXkM22hxS6F_W5oHCmhWJjRp0OjoVHBXyATlOoHTJqPuISLgn_jjRvJtDzCV5_FpOUHFvDXGSIEg8OZnGhHHyoMMdwJFBOK4_z_3Cb26qmEwErO7cCQx_q-uMCXYs [following]
# --2019-08-04 04:32:11--  https://uc7ad1f07f4f92178823a3ba26ae.dl.dropboxusercontent.com/zip_by_token_key?dl=1&key=Al_jctViyDUqPJowLg2KHcFswa7WOLnaPavvl6RnbPeM2quCLI0sBL6rIED0WlvAYQTbw9AtJPM_hkIsWurYeohk5gYvPxU7zZTAC1Reu61mm_331agmMUNAXIuSjX6SUOhT9UGXkM22hxS6F_W5oHCmhWJjRp0OjoVHBXyATlOoHTJqPuISLgn_jjRvJtDzCV5_FpOUHFvDXGSIEg8OZnGhHHyoMMdwJFBOK4_z_3Cb26qmEwErO7cCQx_q-uMCXYs
# Resolving uc7ad1f07f4f92178823a3ba26ae.dl.dropboxusercontent.com (uc7ad1f07f4f92178823a3ba26ae.dl.dropboxusercontent.com)... 162.125.3.6, 2620:100:6018:6::a27d:306
# Connecting to uc7ad1f07f4f92178823a3ba26ae.dl.dropboxusercontent.com (uc7ad1f07f4f92178823a3ba26ae.dl.dropboxusercontent.com)|162.125.3.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘models.zip’
#
# models.zip              [     <=>            ] 633.16M  15.0MB/s    in 51s
#
# 2019-08-04 04:33:03 (12.5 MB/s) - ‘models.zip’ saved [663919589]
#
# Archive:  models.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#   inflating: hand_pose_model.pth
#   inflating: body_pose.caffemodel
#   inflating: hand_pose.caffemodel
#   inflating: body_pose_model.pth
#   inflating: hand_pose_deploy.prototxt
#   inflating: body_pose_deploy.prototxt
# /content/pytorch-openpose

# %% [markdown]
# ## run demo.pyを実行する前の注意
#
# GPUで実行するためには./python/hand.pyの下記のを修正
#
#
# ``` python
# output = self.model(data).numpy()
# ```
#
#          ↓
#
# ``` python
# output = self.model(data).cpu().numpy()
# ```
#
# 修正前にdemo.pyをしてhandをimportしてしまったら
#
#
# ```　python
# import sys
# sys.modules.pop('hand') # Unimport module forcely
# ```
#
# を実行してhandを解除すること

# %%
# スクリプトの修正
with open('./python/hand.py') as f:
  txt = f.read()
with open('./python/hand.py', 'w') as f:
  f.write(txt.replace('output = self.model(data).numpy()',
            'output = self.model(data).cpu().numpy()'))

# %%
run demo.py
