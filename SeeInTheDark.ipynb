# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/june1st/GoogleColab/blob/master/SeeInTheDark.ipynb)

# %% [markdown]
# <img height="60px" src="/img/colab_favicon.ico" align="left" hspace="20px" vspace="5px">
#
# ## See in the Dark のテスト
#
# Colaboratory は、完全にクラウドで実行される Jupyter ノートブック環境です。設定不要で、無料でご利用になれます。詳細については、[よくある質問](https://research.google.com/colaboratory/faq.html)をご覧ください。

# %%
# !git clone https://github.com/cchen156/Learning-to-See-in-the-Dark.git
# Out:
# Cloning into 'Learning-to-See-in-the-Dark'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 134 (delta 2), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (134/134), 459.42 KiB | 20.88 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
cd Learning-to-See-in-the-Dark
# Out:
# /content/Learning-to-See-in-the-Dark

# %%
# !yes | python download_dataset.py
# Out:
# Dowloading Sony subset... (25GB)
# Dowloading Fuji subset... (52GB)
# Archive:  dataset/Sony.zip
#    creating: dataset/Sony/
#    creating: dataset/Sony/long/
#   inflating: dataset/Sony/long/00001_00_10s.ARW
#   inflating: dataset/Sony/long/00002_00_10s.ARW
#   inflating: dataset/Sony/long/00004_00_10s.ARW
#   inflating: dataset/Sony/long/00009_00_10s.ARW
#   inflating: dataset/Sony/long/00010_00_10s.ARW
#   inflating: dataset/Sony/long/00012_00_10s.ARW
#   inflating: dataset/Sony/long/00013_00_10s.ARW
#   inflating: dataset/Sony/long/00014_00_10s.ARW
#   inflating: dataset/Sony/long/00015_00_10s.ARW
#   inflating: dataset/Sony/long/00017_00_10s.ARW
#   inflating: dataset/Sony/long/00018_00_10s.ARW
#   inflating: dataset/Sony/long/00019_00_10s.ARW
#   inflating: dataset/Sony/long/00021_00_10s.ARW
#   inflating: dataset/Sony/long/00023_00_10s.ARW
#   inflating: dataset/Sony/long/00024_00_10s.ARW
#   inflating: dataset/Sony/long/00026_00_10s.ARW
# ...

# %%
# %ls
# Out:
# sample_data/
